# %%
import pandas as pd
data=pd.read_csv("C:\\Users\\Aarav Menon\\OneDrive\\Desktop\\project\\traffic_volume_data.csv")
print(data.head())
# Out:
#           date_time  is_holiday  air_pollution_index  humidity  wind_speed  \
# 0  02-10-2012 15:00           0                  184        64           3
# 1  02-10-2012 16:00           0                  167        64           3
# 2  02-10-2012 17:00           0                  119        63           3
# 3  02-10-2012 18:00           0                  161        63           3
# 4  02-10-2012 19:00           0                  243        62           3
#
#    wind_direction  visibility_in_miles  dew_point  temperature  rain_p_h  ...  \
# 0             328                    7          7       293.17       0.0  ...
# 1             327                    7          7       293.86       0.0  ...
# 2             327                    6          6       294.14       0.0  ...
# 3             326                    3          3       293.10       0.0  ...
# 4             326                    8          8       290.97       0.0  ...
#
#    last_2_hour_traffic  last_3_hour_traffic last_4_hour_traffic  \
# 0                 4918                 5026                4767
# 1                 5181                 4918                5026
# 2                 5584                 5181                4918
# 3                 6015                 5584                5181
# 4                 5791                 6015                5584
#
#   last_5_hour_traffic  last_6_hour_traffic  hour  month_day  weekday  month  \
# 0                4516                 5545    15          2        2     10
# 1                4767                 4516    16          2        2     10
# 2                5026                 4767    17          2        2     10
# 3                4918                 5026    18          2        2     10
# 4                5181                 4918    19          2        2     10
#
#    year
# 0  2012
# 1  2012
# 2  2012
# 3  2012
# 4  2012
#
# [5 rows x 26 columns]

# %%
print(data.isnull().sum())
# Out:
# date_time              0
# is_holiday             0
# air_pollution_index    0
# humidity               0
# wind_speed             0
# wind_direction         0
# visibility_in_miles    0
# dew_point              0
# temperature            0
# rain_p_h               0
# snow_p_h               0
# clouds_all             0
# weather_type           0
# weather_description    0
# traffic_volume         0
# last_1_hour_traffic    0
# last_2_hour_traffic    0
# last_3_hour_traffic    0
# last_4_hour_traffic    0
# last_5_hour_traffic    0
# last_6_hour_traffic    0
# hour                   0
# month_day              0
# weekday                0
# month                  0
# year                   0
# dtype: int64

# %%
#making it numeric
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
data['weather_type']=encoder.fit_transform(data['weather_type'])

# %%
print(data[['is_holiday', 'weather_type', 'weather_description']].head())
# Out:
#    is_holiday  weather_type weather_description
# 0           0             0        sky is clear
# 1           0             0        sky is clear
# 2           0             1          few clouds
# 3           0             1          few clouds
# 4           0             1          few clouds

# %%
#normalize everything except last 2 hours traffic etc. because they are very big and dont need to be normalized
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
#numerical_features=['air_pollution_index','humidity','wind_speed','visibility_in_miles','dew_point','temperature','clouds_all']
numerical_features=['air_pollution_index','humidity','wind_speed','visibility_in_miles','dew_point','temperature','clouds_all','traffic_volume', 'last_1_hour_traffic',
       'last_2_hour_traffic', 'last_3_hour_traffic', 'last_4_hour_traffic',
       'last_5_hour_traffic', 'last_6_hour_traffic']
data[numerical_features]=scaler.fit_transform(data[numerical_features])

# %%
print(data.head())
# Out:
#           date_time  is_holiday  air_pollution_index  humidity  wind_speed  \
# 0  02-10-2012 15:00           0             0.348169 -0.427772      -0.184
# 1  02-10-2012 16:00           0             0.145140 -0.427772      -0.184
# 2  02-10-2012 17:00           0            -0.428118 -0.487108      -0.184
# 3  02-10-2012 18:00           0             0.073483 -0.487108      -0.184
# 4  02-10-2012 19:00           0             1.052798 -0.546445      -0.184
#
#    wind_direction  visibility_in_miles  dew_point  temperature  rain_p_h  ...  \
# 0             328             0.782124   0.782124     0.976639       0.0  ...
# 1             327             0.782124   0.782124     1.028072       0.0  ...
# 2             327             0.393011   0.393011     1.048943       0.0  ...
# 3             326            -0.774328  -0.774328     0.971421       0.0  ...
# 4             326             1.171237   1.171237     0.812651       0.0  ...
#
#    last_2_hour_traffic  last_3_hour_traffic  last_4_hour_traffic  \
# 0             0.842573             0.896754             0.766660
# 1             0.974635             0.842524             0.896712
# 2             1.176996             0.974585             0.842482
# 3             1.393417             1.176945             0.974542
# 4             1.280938             1.393364             1.176901
#
#   last_5_hour_traffic  last_6_hour_traffic  hour  month_day  weekday  month  \
# 0            0.640591             1.157215    15          2        2     10
# 1            0.766625             0.640532    16          2        2     10
# 2            0.896677             0.766565    17          2        2     10
# 3            0.842447             0.896614    18          2        2     10
# 4            0.974507             0.842385    19          2        2     10
#
#    year
# 0  2012
# 1  2012
# 2  2012
# 3  2012
# 4  2012
#
# [5 rows x 26 columns]

# %%
#removing date and other columns
data.drop(columns=['date_time'],inplace=True)
data.drop(columns=['is_holiday'],inplace=True)
data.drop(columns=['hour'],inplace=True)
data.drop(columns=['month_day'],inplace=True)
data.drop(columns=['weekday'],inplace=True)
data.drop(columns=['month'],inplace=True)
data.drop(columns=['year'],inplace=True)
data.drop(columns=['rain_p_h'],inplace=True)
data.drop(columns=['snow_p_h'],inplace=True)
data.drop(columns=['weather_description'],inplace=True)

print(data.head())
# Out:
#    air_pollution_index  humidity  wind_speed  wind_direction  \
# 0             0.348169 -0.427772      -0.184             328
# 1             0.145140 -0.427772      -0.184             327
# 2            -0.428118 -0.487108      -0.184             327
# 3             0.073483 -0.487108      -0.184             326
# 4             1.052798 -0.546445      -0.184             326
#
#    visibility_in_miles  dew_point  temperature  clouds_all  weather_type  \
# 0             0.782124   0.782124     0.976639   -1.272298             0
# 1             0.782124   0.782124     1.028072   -1.272298             0
# 2             0.393011   0.393011     1.048943   -0.783514             1
# 3            -0.774328  -0.774328     0.971421   -0.783514             1
# 4             1.171237   1.171237     0.812651   -0.783514             1
#
#    traffic_volume  last_1_hour_traffic  last_2_hour_traffic  \
# 0        1.177103             0.974685             0.842573
# 1        1.393524             1.177046             0.974635
# 2        1.281046             1.393466             1.176996
# 3        0.768365             1.280988             1.393417
# 4        0.150236             0.768307             1.280938
#
#    last_3_hour_traffic  last_4_hour_traffic  last_5_hour_traffic  \
# 0             0.896754             0.766660             0.640591
# 1             0.842524             0.896712             0.766625
# 2             0.974585             0.842482             0.896677
# 3             1.176945             0.974542             0.842447
# 4             1.393364             1.176901             0.974507
#
#    last_6_hour_traffic
# 0             1.157215
# 1             0.640532
# 2             0.766565
# 3             0.896614
# 4             0.842385

# %%
# Count the occurrences of each entry in the weather_description column
entry_counts = data['weather_type'].value_counts()

# Filter out entries with counts less than a threshold (e.g., 100)
threshold = 100
filtered_entries = entry_counts[entry_counts >= threshold]

# Filter the dataframe based on the filtered entries
data = data[data['weather_type'].isin(filtered_entries.index)]

# Print the filtered dataframe
print(data)
# Out:
#        air_pollution_index  humidity  wind_speed  wind_direction  \
# 0                 0.348169 -0.427772   -0.184000             328
# 1                 0.145140 -0.427772   -0.184000             327
# 2                -0.428118 -0.487108   -0.184000             327
# 3                 0.073483 -0.487108   -0.184000             326
# 4                 1.052798 -0.546445   -0.184000             326
# ...                    ...       ...         ...             ...
# 33739            -0.965547  0.818290   -1.156798             328
# 33740            -0.881946 -0.071754   -1.156798              24
# 33741            -0.201203 -0.071754   -1.156798              24
# 33742             0.885598 -0.309100   -1.156798              42
# 33743            -0.177317 -0.487108   -1.156798              27
#
#        visibility_in_miles  dew_point  temperature  clouds_all  weather_type  \
# 0                 0.782124   0.782124     0.976639   -1.272298             0
# 1                 0.782124   0.782124     1.028072   -1.272298             0
# 2                 0.393011   0.393011     1.048943   -0.783514             1
# 3                -0.774328  -0.774328     0.971421   -0.783514             1
# 4                 1.171237   1.171237     0.812651   -0.783514             1
# ...                    ...        ...          ...         ...           ...
# 33739             0.782124   0.782124     0.582322    1.017268             5
# 33740            -1.163442  -1.163442     0.512999    1.017268             6
# 33741            -1.552555  -1.552555     0.512999    1.017268             5
# 33742             0.393011   0.393011     0.423551    1.017268             6
# 33743             1.171237   1.171237     0.423551    1.017268             5
#
#        traffic_volume  last_1_hour_traffic  last_2_hour_traffic  \
# 0            1.177103             0.974685             0.842573
# 1            1.393524             1.177046             0.974635
# 2            1.281046             1.393466             1.176996
# 3            0.768365             1.280988             1.393417
# 4            0.150236             0.768307             1.280938
# ...               ...                  ...                  ...
# 33739       -0.447808            -0.447865            -0.447920
# 33740       -0.525137            -0.447865            -0.447920
# 33741       -0.525137            -0.525194            -0.447920
# 33742       -0.959987            -0.525194            -0.525249
# 33743       -0.959987            -0.960043            -0.525249
#
#        last_3_hour_traffic  last_4_hour_traffic  last_5_hour_traffic  \
# 0                 0.896754             0.766660             0.640591
# 1                 0.842524             0.896712             0.766625
# 2                 0.974585             0.842482             0.896677
# 3                 1.176945             0.974542             0.842447
# 4                 1.393364             1.176901             0.974507
# ...                    ...                  ...                  ...
# 33739            -0.254637            -0.254674            -0.254706
# 33740            -0.447959            -0.254674            -0.254706
# 33741            -0.447959            -0.447995            -0.254706
# 33742            -0.447959            -0.447995            -0.448026
# 33743            -0.525287            -0.447995            -0.448026
#
#        last_6_hour_traffic
# 0                 1.157215
# 1                 0.640532
# 2                 0.766565
# 3                 0.896614
# 4                 0.842385
# ...                    ...
# 33739            -0.052394
# 33740            -0.254749
# 33741            -0.254749
# 33742            -0.254749
# 33743            -0.448066
#
# [33723 rows x 16 columns]

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU, Input
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

# Assuming 'data' is your DataFrame containing the preprocessed dataset

# Split data into features (X) and target variable (y)
X = data.drop(columns=['traffic_volume'])  # Features
y = data['traffic_volume']  # Target variable

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Define the GRU model
model = Sequential([
    Input(shape=(X_train.shape[1],)),  # Input layer with shape inferred from the training data
    tf.keras.layers.Reshape((X_train.shape[1], 1)),  # Reshape for compatibility with GRU layer
    GRU(units=64),
    Dense(units=1)
])

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.2)

# Make predictions
y_pred = model.predict(X_test)

# Calculate Mean Squared Error
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error (GRU):", mse)
# Out:
# Epoch 1/10
# 675/675 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - loss: 0.4885 - val_loss: 0.2434
# Epoch 2/10
# 675/675 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.2122 - val_loss: 0.1642
# Epoch 3/10
# 675/675 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.1515 - val_loss: 0.1453
# Epoch 4/10
# 675/675 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.1239 - val_loss: 0.1228
# Epoch 5/10
# 675/675 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.1214 - val_loss: 0.1184
# Epoch 6/10
# 675/675 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.1108 - val_loss: 0.1134
# Epoch 7/10
# 675/675 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.1023 - val_loss: 0.1166
# Epoch 8/10
# 675/675 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0990 - val_loss: 0.1080
# Epoch 9/10
# 675/675 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.1002 - val_loss: 0.1056
# Epoch 10/10
# 675/675 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0935 - val_loss: 0.0982
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Mean Squared Error (GRU): 0.09515018717792494
